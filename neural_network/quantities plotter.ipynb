# %%
import numpy as np

import pandas as pd

from tqdm import tqdm

def read_tree(tree_path):
    
    df = pd.read_csv(tree_path)
    tqdm.pandas()
    df.progress_apply(lambda x: x**2) 
    return df


from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi']  = 250
plt.rcParams['savefig.dpi'] = 250

# %%
vincia = read_tree("vincia.csv")
simple = read_tree("simple_shower.csv")
# Out:
# /home/joaohumbg/.local/lib/python3.10/site-packages/tqdm/std.py:775: RuntimeWarning: divide by zero encountered in long_scalars
#   total = df.size // df.shape[axis]
# 1it [00:00, 592.83it/s]
# /home/joaohumbg/.local/lib/python3.10/site-packages/tqdm/std.py:775: RuntimeWarning: divide by zero encountered in long_scalars
#   total = df.size // df.shape[axis]
# 1it [00:00, 598.67it/s]

# %%
header = list (simple.columns) 
header = ",".join(header)
header
# Out:
# 'ln_Delta1,ln_k1,ln_Delta2,ln_k2,ln_Delta3,ln_k3,ln_Delta4,ln_k4,pT_j1,pT_j2,eta_j1,eta_j2,phi_j1,phi_j2,delta_phi,pT_j1_cut,pT_j2_cut,eta_j1_cut,eta_j2_cut,phi_j1_cut,phi_j2_cut,delta_phi_cut'

# %%
print ('Simple shower events kept: ', len(simple))
print ('Vincia events kept:        ', len(vincia))

print ('\n')
print ("""ATTENTION HERE: BE SURE THAT THERE WERE ORIGINALLY 1M EVENTS
CHECK THE SETTINGS FOLDER\n""")

print ('Percentage of Simple events kept: ', round (len(simple)/1e6 * 100, 2) ,'%')
print ('Percentage of Vincia events kept: ', round (len(vincia)/1e6 * 100, 2) ,'%')
# Out:
# Simple shower events kept:  0
# Vincia events kept:         0
#
#
# ATTENTION HERE: BE SURE THAT THERE WERE ORIGINALLY 1M EVENTS
# CHECK THE SETTINGS FOLDER
#
# Percentage of Simple events kept:  0.0 %
# Percentage of Vincia events kept:  0.0 %

# %%
simple
# Out:
# Empty DataFrame
# Columns: [ln_Delta1, ln_k1, ln_Delta2, ln_k2, ln_Delta3, ln_k3, ln_Delta4, ln_k4, pT_j1, pT_j2, eta_j1, eta_j2, phi_j1, phi_j2, delta_phi, pT_j1_cut, pT_j2_cut, eta_j1_cut, eta_j2_cut, phi_j1_cut, phi_j2_cut, delta_phi_cut]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Ensure that cuts are being done correctly
print(f'min(pT_j1_cut)     = {min(vincia.pT_j1_cut)}')
#print(f'min(pT_j2_cut)     = {min(vincia.pT_j2_cut)}')
print(f'max(eta_j1_cut)    = {max(vincia.eta_j1_cut)}')
#print(f'max(eta_j2_cut)    = {max(vincia.eta_j2_cut)}')
#print(f'min(delta_phi_cut) = {min(vincia.delta_phicut)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 2
#       1 # Ensure that cuts are being done correctly
# ----> 2 print(f'min(pT_j1_cut)     = {min(vincia.pT_j1_cut)}')
#       3 #print(f'min(pT_j2_cut)     = {min(vincia.pT_j2_cut)}')
#       4 print(f'max(eta_j1_cut)    = {max(vincia.eta_j1_cut)}')
#
# ValueError: min() arg is an empty sequence

# %% [markdown]
# # Plot orignal quantities

# %%
label = {'ln_z1': '$\ln z_1$',
         'ln_z2': '$\ln z_2$',
         'ln_z3': '$\ln z_3$',
         'ln_z4': '$\ln z_4$',
         'ln_Delta1': '$\ln (1/\Delta_1)$',
         'ln_Delta2': '$\ln (1/\Delta_2)$',
         'ln_Delta3': '$\ln (1/\Delta_3)$',
         'ln_Delta4': '$\ln (1/\Delta_4)$',
         #'ln_Delta1': '$-1/ \ln \Delta_1$',
         #'ln_Delta2': '$-1/ \ln \Delta_2$',
         #'ln_Delta3': '$-1/ \ln \Delta_3$',
         #'ln_Delta4': '$-1/ \ln \Delta_4$',
         'ln_k1': '$\ln \kappa_1$',
         'ln_k2': '$\ln \kappa_2$',
         'ln_k3': '$\ln \kappa_3$',
         'ln_k4': '$\ln \kappa_4$',
         'j1_multiplicity1': '$j_1$ Multiplicity',
         'j2_multiplicity1': '$j_2$ Multiplicity',
         'pT_j1'        : '$p_T (j_1)$',
         'pT_j2'        : '$p_T (j_2)$',
         'eta_j1'       : '$\eta (j_1)$',
         'eta_j2'       : '$\eta (j_2)$',
         'phi_j1'       : '$\phi (j_1)$',
         'phi_j2'       : '$\phi (j_2)$',
         'delta_phi'    : '$\Delta \phi$',
         'pT_j1_cut'    : '$p_T (j_1) (cut)$',
         'pT_j2_cut'    : '$p_T (j_2) (cut)$',
         'eta_j1_cut'   : '$\eta (j_1) (cut)$',
         'eta_j2_cut'   : '$\eta (j_2) (cut)$',
         'phi_j1_cut'   : '$\phi (j_1) (cut)$',
         'phi_j2_cut'   : '$\phi (j_2) (cut)$',
         'delta_phi_cut': '$\Delta \phi (cut)$',
        }

# %% [markdown]
# plt.hist(vincia.ln_Delta1, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Vincia')
# plt.hist(simple.ln_Delta1, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Simple Shower')
# plt.title('-1/$\ln \Delta_1$')
# plt.xlabel('-1/$\ln \Delta_1$')
# plt.legend()
# plt.savefig('plots/quantities/original/Delta1.png')
# plt.show()
#
#
# plt.hist(vincia.ln_Delta2, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Vincia')
# plt.hist(simple.ln_Delta2, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Simple Shower')
# plt.title('-1/$\ln \Delta_2$')
# plt.xlabel('-1/$\ln \Delta_2$')
# plt.legend()
# plt.savefig('plots/quantities/original/Delta2.png')
# plt.show()
#
#
# plt.hist(vincia.ln_Delta3, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Vincia')
# plt.hist(simple.ln_Delta3, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Simple Shower')
# plt.title('$\ln \Delta_3$')
# plt.xlabel('$\ln \Delta_3$')
# plt.legend()
# plt.savefig('plots/quantities/original/Delta3.png')
# plt.show()
#
#
# plt.hist(vincia.ln_Delta4, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Vincia')
# plt.hist(simple.ln_Delta4, histtype = 'step', density = True, bins = 100, range = [0,2], label = 'Simple Shower')
# plt.title('$\ln \Delta_4$')
# plt.xlabel('$\ln \Delta_4$')
# plt.legend()
# plt.savefig('plots/quantities/original/Delta4.png')
# plt.show()
#
#
#
#
# plt.hist(vincia.ln_k1, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Vincia')
# plt.hist(simple.ln_k1, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Simple Shower')
# plt.title('$\ln \kappa_1$')
# plt.xlabel('$\ln \kappa_1$')
# plt.legend(loc='upper left')
# plt.savefig('plots/quantities/original/k1.png')
# plt.show()
#
# plt.hist(vincia.ln_k2, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Vincia')
# plt.hist(simple.ln_k2, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Simple Shower')
# plt.title('$\ln \kappa_2$')
# plt.xlabel('$\ln \kappa_2$')
# plt.legend()
# plt.savefig('plots/quantities/original/k2.png')
# plt.show()
#
# plt.hist(vincia.ln_k3, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Vincia')
# plt.hist(simple.ln_k3, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Simple Shower')
# plt.title('$\ln \kappa_3$')
# plt.xlabel('$\ln \kappa_3$')
# plt.legend()
# plt.savefig('plots/quantities/original/k3.png')
# plt.show()
#
# plt.hist(vincia.ln_k4, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Vincia')
# plt.hist(simple.ln_k4, histtype = 'step', density = True, bins = 100, range = [-12,0], label = 'Simple Shower')
# plt.title('$\ln \kappa_4$')
# plt.xlabel('$\ln \kappa_4$')
# plt.legend()
# plt.savefig('plots/quantities/original/k4.png')
# plt.show()
# """
#
# plt.hist(vincia.z1, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Vincia')
# plt.hist(simple.z1, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Simple Shower')
# plt.title('$z_1$')
# plt.xlabel('$z_1$')
# plt.legend()
# plt.savefig('plots/quantities/original/z1.png')
# plt.show()
#
# plt.hist(vincia.z2, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Vincia')
# plt.hist(simple.z2, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Simple Shower')
# plt.title('$z_2$')
# plt.xlabel('$z_2$')
# plt.legend()
# plt.savefig('plots/quantities/original/z2.png')
# plt.show()
#
# plt.hist(vincia.z3, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Vincia')
# plt.hist(simple.z3, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Simple Shower')
# plt.title('$z_3$')
# plt.xlabel('$z_3$')
# plt.legend()
# plt.savefig('plots/quantities/original/z3.png')
# plt.show()
#
# plt.hist(vincia.z4, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Vincia')
# plt.hist(simple.z4, histtype = 'step', density = True, bins = 100, range = [0,0.5], label = 'Simple Shower')
# plt.title('$z_4$')
# plt.xlabel('$z_4$')
# plt.legend()
# plt.savefig('plots/quantities/original/z4.png')
# plt.show()
#
# plt.hist(vincia.soft_drops, histtype = 'step', density = True, range = [0,10], label = 'Vincia')
# plt.hist(simple.soft_drops, histtype = 'step', density = True, range = [0,10], label = 'Simple Shower')
# plt.title('Soft drops')
# plt.xlabel('Soft drops')
# plt.legend()
# plt.savefig('plots/quantities/original/softdrops.png')
# plt.show()
# """

# %%
for i in vincia:
    plt.hist(vincia[i], histtype = 'step', density = True, bins = 100, label = 'Vincia')
    plt.hist(simple[i], histtype = 'step', density = True, bins = 100, label = 'Simple Shower')
    plt.title(label[i])
    plt.xlabel(label[i])
    if i == "pT_j2_cut":
        plt.yscale('log')
    plt.legend()
    plt.savefig(f'plots/quantities/original/{i}.png')
    plt.show()

# %%
import matplotlib.colors as mcolors

for i in vincia:
    for j in vincia:
        
        for k in range(1,5):
            if (i == 'ln_Delta'+str(k) ) and (j == 'ln_k' + str(k)):
            
                h_vincia, vincia_xedges, vincia_yedges, vincia_image = plt.hist2d (vincia[i], vincia[j], bins = 100, density = True)
                plt.xlabel(label[i])
                plt.ylabel(label[j])
                plt.title('Vincia: ' + label[i] + ' vs. ' + label[j])
                #plt.legend()
                plt.colorbar()
                plt.savefig('plots/quantities/2d/vincia_' + str(i) + '_vs_' + str(j))
                plt.show()

                h_simple, simple_xedges, simple_yedges, simple_image = plt.hist2d (simple[i], simple[j], bins = 100, density = True)
                plt.xlabel(label[i])
                plt.ylabel(label[j])
                plt.title('Simple shower: ' + label[i] + ' vs. ' + label[j])
                #plt.legend()
                plt.colorbar()
                plt.savefig('plots/quantities/2d/simple_' + str(i) + '_vs_' + str(j))
                plt.show()

                plt.figure(3)
                plt.pcolormesh(vincia_xedges, vincia_yedges, (h_vincia-h_simple).T)
                plt.xlabel(label[i])
                plt.ylabel(label[j])
                plt.colorbar()
                plt.title('Difference betweeen Vincia and Simple Shower: ' + label[i] + ' vs. ' + label[j])

                plt.savefig('plots/quantities/2d/difference_' + str(i) + '_vs_' + str(j))
                plt.show()

# %% [markdown]
# # Training, validation, and test sets

# %%
train_simple = read_tree("csv/train_simple.csv")
train_vincia = read_tree("csv/train_vincia.csv")
valid_simple = read_tree("csv/valid_simple.csv")
valid_vincia = read_tree("csv/valid_vincia.csv")
test_simple  = read_tree("csv/test_simple.csv" )
test_vincia  = read_tree("csv/test_vincia.csv" )
full_simple  = read_tree("csv/full_simple.csv" )
full_vincia  = read_tree("csv/full_vincia.csv" )

# %%
full_simple2 = train_simple.append(valid_simple).append(test_simple)
full_vincia2 = train_vincia.append(valid_vincia).append(test_vincia)

# %% [markdown]
# **Comparison between samples for Simple Shower**

# %%
plt.hist(train_simple.ln_Delta1, histtype = 'step', density = True, bins = 100,  label = 'Train')
plt.hist(valid_simple.ln_Delta1, histtype = 'step', density = True, bins = 100,  label = 'Valid')
plt.hist(test_simple.ln_Delta1 , histtype = 'step', density = True, bins = 100,  label = 'Test')
plt.hist(simple.ln_Delta1      , histtype = 'step', density = True, bins = 100,  label = 'Full Sample')

plt.title('$\ln \Delta_1$ Simple')
plt.xlabel('$\ln \Delta_1$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_Delta1.png')
plt.show()

plt.hist(train_simple.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_Delta2 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_Delta2      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_2$ Simple')
plt.xlabel('$\ln \Delta_2$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_Delta2.png')
plt.show()

plt.hist(train_simple.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_Delta3 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_Delta3      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_3$ Simple')
plt.xlabel('$\ln \Delta_3$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_Delta3.png')
plt.show()

plt.hist(train_simple.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_Delta4 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_Delta4      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_4$ Simple')
plt.xlabel('$\ln \Delta_4$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_Delta4.png')
plt.show()

plt.hist(train_simple.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_k1 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_k1      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_1$ Simple')
plt.xlabel('$\ln \kappa_1$')
plt.legend(loc='upper left')
plt.savefig('plots/quantities/train_valid_test/Simple_k1.png')
plt.show()

plt.hist(train_simple.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_k2 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_k2      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_2$ Simple')
plt.xlabel('$\ln \kappa_2$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_k2.png')
plt.show()

plt.hist(train_simple.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_k3 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_k3      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_3$ Simple')
plt.xlabel('$\ln \kappa_3$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_k3.png')
plt.show()

plt.hist(train_simple.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_simple.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_simple.ln_k4 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(simple.ln_k4      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_4$ Simple')
plt.xlabel('$\ln \kappa_4$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Simple_k4.png')
plt.show()

# %% [markdown]
# **Comparison between samples for Vincia**

# %%
plt.hist(train_vincia.ln_Delta1, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_Delta1, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_Delta1 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_Delta1      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_1$ Vincia')
plt.xlabel('$\ln \Delta_1$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_Delta1.png')
plt.show()

plt.hist(train_vincia.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_Delta2 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_Delta2      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_2$ Vincia')
plt.xlabel('$\ln \Delta_2$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_Delta2.png')
plt.show()

plt.hist(train_vincia.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_Delta3 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_Delta3      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_3$ Vincia')
plt.xlabel('$\ln \Delta_3$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_Delta3.png')
plt.show()

plt.hist(train_vincia.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_Delta4 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_Delta4      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \Delta_4$ Vincia')
plt.xlabel('$\ln \Delta_4$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_Delta4.png')
plt.show()

plt.hist(train_vincia.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_k1 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_k1      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_1$ Vincia')
plt.xlabel('$\ln \kappa_1$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_k1.png')
plt.show()

plt.hist(train_vincia.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_k2 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_k2      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_2$ Vincia')
plt.xlabel('$\ln \kappa_2$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_k2.png')
plt.show()

plt.hist(train_vincia.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_k3 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_k3      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_3$ Vincia')
plt.xlabel('$\ln \kappa_3$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_k3.png')
plt.show()

plt.hist(train_vincia.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Train')
plt.hist(valid_vincia.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Valid')
plt.hist(test_vincia.ln_k4 , histtype = 'step', density = True, bins = 100, label = 'Test')
plt.hist(vincia.ln_k4      , histtype = 'step', density = True, bins = 100, label = 'Full Sample')
plt.title('$\ln \kappa_4$ Vincia')
plt.xlabel('$\ln \kappa_4$')
plt.legend()
plt.savefig('plots/quantities/train_valid_test/Vincia_k4.png')
plt.show()

# %% [markdown]
# **Training vs. test**

# %%
plt.hist(train_simple.ln_Delta1, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_Delta1 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_Delta1, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_Delta1 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \Delta_1$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \Delta_1$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/Delta1.png')
plt.show()

plt.hist(train_simple.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_Delta2 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_Delta2, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_Delta2 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \Delta_2$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \Delta_2$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/Delta2.png')
plt.show()

plt.hist(train_simple.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_Delta3 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_Delta3, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_Delta3 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \Delta_3$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \Delta_3$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/Delta3.png')
plt.show()

plt.hist(train_simple.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_Delta4 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_Delta4, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_Delta4 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \Delta_4$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \Delta_4$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/Delta4.png')
plt.show()

plt.hist(train_simple.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_k1 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_k1, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_k1 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \kappa_1$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \kappa_1$')
plt.legend(loc='upper left')
plt.savefig('plots/quantities/compare_train_test/k1.png')
plt.show()

plt.hist(train_simple.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_k2 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_k2, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_k2 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \kappa_2$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \kappa_2$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/k2.png')
plt.show()

plt.hist(train_simple.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_k3 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_k3, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_k3 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \kappa_3$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \kappa_3$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/k3.png')
plt.show()

plt.hist(train_simple.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Simple Train')
plt.hist(test_simple.ln_k4 , histtype = 'step', density = True, bins = 100, label = 'Simple Test')
plt.hist(train_vincia.ln_k4, histtype = 'step', density = True, bins = 100, label = 'Vincia Train')
plt.hist(test_vincia.ln_k4 , histtype = 'step', density = True, bins = 100, label = 'Vincia Test')
plt.title('$\ln \kappa_4$ Train vs. Test Vincia/Simple')
plt.xlabel('$\ln \kappa_4$')
plt.legend()
plt.savefig('plots/quantities/compare_train_test/k4.png')
plt.show()

# %% [markdown]
# # Neural network output

# %%
predicted_vincia = read_tree("csv/predicted_vincia.csv")
predicted_simple = read_tree("csv/predicted_simple.csv")

# %%
for i in predicted_vincia:
    plt.hist(vincia[i]          , histtype = 'step', density = True, bins = 100, label = 'Vincia')
    plt.hist(predicted_vincia[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Vincia')
    plt.hist(simple[i]          , histtype = 'step', density = True, bins = 100, label = 'Simple')
    plt.hist(predicted_simple[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Simple')
    plt.hist(simple[i], histtype = 'step', density = True, bins = 100, label = 'Simple Shower')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/predicted/{i}.png')
    plt.show()
    
for i in predicted_vincia:
    plt.hist(vincia[i]          , histtype = 'step', density = True, bins = 100, label = 'Vincia')
    plt.hist(predicted_vincia[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Vincia')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/predicted/Vincia_{i}.png')
    plt.show()
    
for i in predicted_simple:
    plt.hist(simple[i]          , histtype = 'step', density = True, bins = 100, label = 'Simple')
    plt.hist(predicted_simple[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Simple')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/predicted/Simple_{i}.png')
    plt.show()

# %%
print(f"len(predicted_vincia) = {len(predicted_vincia)}")
print(f"len(predicted_simple) = {len(predicted_simple)}")

# %% [markdown]
# # Confident and doubtfult results

# %%
confident_vincia = read_tree("csv/confident_vincia.csv")
confident_simple = read_tree("csv/confident_simple.csv")

# %%
for i in confident_vincia:
    plt.hist(vincia[i]          , histtype = 'step', density = True, bins = 100, label = 'Vincia')
    plt.hist(confident_vincia[i], histtype = 'step', density = True, bins = 100, label = 'Confident Vincia')
    plt.hist(simple[i]          , histtype = 'step', density = True, bins = 100, label = 'Simple')
    plt.hist(predicted_simple[i], histtype = 'step', density = True, bins = 100, label = 'Confident Simple')
    plt.hist(simple[i], histtype = 'step', density = True, bins = 100, label = 'Simple Shower')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/confident/{i}.png')
    plt.show()
    
for i in predicted_vincia:
    plt.hist(vincia[i]          , histtype = 'step', density = True, bins = 100, label = 'Vincia')
    plt.hist(predicted_vincia[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Vincia')
    plt.hist(simple[i], histtype = 'step', density = True, bins = 100, label = 'Simple Shower')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/confident/Vincia_{i}.png')
    plt.show()
    
for i in predicted_simple:
    plt.hist(simple[i]          , histtype = 'step', density = True, bins = 100, label = 'Simple')
    plt.hist(predicted_simple[i], histtype = 'step', density = True, bins = 100, label = 'Predicted Simple')
    plt.title(label[i])
    plt.xlabel(label[i])
    plt.legend()
    plt.savefig(f'plots/quantities/confident/Simple_{i}.png')
    plt.show()

# %%
print(f"len(confident_vincia) = {len(confident_vincia)}")
print(f"len(confident_simple) = {len(confident_simple)}")
